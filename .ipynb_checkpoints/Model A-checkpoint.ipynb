# %%
import tensorflow as tf
from pathlib import Path
import matplotlib.pyplot as plt

# ====================================================
# 1. Global config
# ====================================================
IMG_SIZE = 224
BATCH_SIZE = 32
SEED = 1337

root_dir = Path("/data/classes/2025/fall/cs426/bartlecg5526/group_2/chest_xray")
train_dir = root_dir / "train"           # NORMAL / PNEUMONIA(/bacteria,virus)
test_dir  = root_dir / "test"            # NORMAL / PNEUMONIA(/bacteria,virus)
train_pneu_dir = train_dir / "PNEUMONIA" # bacteria / virus
test_pneu_dir  = test_dir / "PNEUMONIA"  # bacteria / virus

AUTOTUNE = tf.data.AUTOTUNE

# %%
# ====================================================
# 2. Preprocess + prepare helper
# ====================================================
def preprocess(image, label):
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

def prepare(ds, shuffle=False, repeat=False):
    if shuffle:
        ds = ds.shuffle(1000, seed=SEED)
    if repeat:
        ds = ds.repeat()
    ds = ds.map(preprocess, num_parallel_calls=AUTOTUNE)
    ds = ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)
    return ds

# %%
# ====================================================
# 3. Task A1: NORMAL vs PNEUMONIA
#    - use train/ (NORMAL, PNEUMONIA)
#    - test/ as fixed test set
#    - 10% of train used as validation
# ====================================================
# Load full training (unbatched) and test
train_full_A1 = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=(IMG_SIZE, IMG_SIZE),
    shuffle=True,
    seed=SEED,
    batch_size=None,
)

test_raw_A1 = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    image_size=(IMG_SIZE, IMG_SIZE),
    shuffle=False,
    seed=SEED,
    batch_size=None,
)

print("A1 classes:", train_full_A1.class_names)  # ['NORMAL', 'PNEUMONIA']

total_train_A1 = train_full_A1.cardinality().numpy()
val_size_A1 = int(0.10 * total_train_A1)
train_size_A1 = total_train_A1 - val_size_A1

train_raw_A1 = train_full_A1.take(train_size_A1)
val_raw_A1   = train_full_A1.skip(train_size_A1)

# --- A1 subsets ---
total_train_A1 = train_raw_A1.cardinality().numpy()

def make_A1_subset(fraction):
    n = int(total_train_A1 * fraction)
    subset_raw = train_raw_A1.take(n)
    return prepare(subset_raw, shuffle=True)

train_A1_10  = make_A1_subset(0.10)
train_A1_25  = make_A1_subset(0.25)
train_A1_50  = make_A1_subset(0.50)
train_A1_100 = prepare(train_raw_A1, shuffle=True)  # full pool

val_A1 = prepare(val_raw_A1)
test_A1 = prepare(test_raw_A1)
# Out:
# Found 5232 files belonging to 2 classes.
# Found 624 files belonging to 2 classes.
# A1 classes: ['NORMAL', 'PNEUMONIA']

# %%
# ====================================================
# 4. Task A2: BACTERIA vs VIRUS (pneumonia only)
#    - use train/PNEUMONIA (bacteria, virus)
#    - test/PNEUMONIA as fixed test
#    - 10% of pneumonia-train used as validation
# ====================================================
train_full_A2 = tf.keras.utils.image_dataset_from_directory(
    train_pneu_dir,
    image_size=(IMG_SIZE, IMG_SIZE),
    shuffle=True,
    seed=SEED,
    batch_size=None,
)

test_raw_A2 = tf.keras.utils.image_dataset_from_directory(
    test_pneu_dir,
    image_size=(IMG_SIZE, IMG_SIZE),
    shuffle=False,
    seed=SEED,
    batch_size=None,
)

print("A2 classes:", train_full_A2.class_names)  # ['bacteria', 'virus']

total_train_A2 = train_full_A2.cardinality().numpy()
val_size_A2 = int(0.10 * total_train_A2)
train_size_A2 = total_train_A2 - val_size_A2

train_raw_A2 = train_full_A2.take(train_size_A2)
val_raw_A2   = train_full_A2.skip(train_size_A2)

# --- A2 subsets ---
total_train_A2 = train_raw_A2.cardinality().numpy()

def make_A2_subset(fraction):
    n = int(total_train_A2 * fraction)
    subset_raw = train_raw_A2.take(n)
    return prepare(subset_raw, shuffle=True)

train_A2_10  = make_A2_subset(0.10)
train_A2_25  = make_A2_subset(0.25)
train_A2_50  = make_A2_subset(0.50)
train_A2_100 = prepare(train_raw_A2, shuffle=True)

val_A2 = prepare(val_raw_A2, repeat=True)
test_A2 = prepare(test_raw_A2)

val_steps_A2 = max(1, val_raw_A2.cardinality().numpy() // BATCH_SIZE)
# Out:
# Found 3883 files belonging to 2 classes.
# Found 390 files belonging to 2 classes.
# A2 classes: ['bacteria', 'virus']

# %%
# ====================================================
# 5. Shared model definition: MobileNetV2 from scratch
# ====================================================
def make_backbone():
    return tf.keras.applications.MobileNetV2(
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
        include_top=False,
        weights=None,      # from scratch
        pooling='avg'
    )

def make_classifier(num_classes):
    backbone = make_backbone()
    inputs = tf.keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = backbone(inputs, training=True)
    outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)
    model = tf.keras.Model(inputs, outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-3),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

# %%
from collections import OrderedDict

# ====================================================
# 6. Train Model A1 (NORMAL vs PNEUMONIA)
# ====================================================
EPOCHS = 20
a1_subsets = {
    "10%": train_A1_10,
    "25%": train_A1_25,
    "50%": train_A1_50,
    "100%": train_A1_100,
}

histories_A1 = {}
tests_A1 = {}
models_A1 = OrderedDict()  

for name, train_ds in a1_subsets.items():
    print(f"\n=== A1 training on {name} of pool ===")
    model = make_classifier(num_classes=2)
    history = model.fit(
        train_ds,
        epochs=EPOCHS,
        validation_data=val_A1,
    )
    histories_A1[name] = history.history
    tests_A1[name] = model.evaluate(test_A1, return_dict=True)
    models_A1[name] = model             # <--- keep trained model

print("A1 test metrics per subset:", tests_A1)
# Out:
# === A1 training on 10% of pool ===
# Epoch 1/20
# 15/15 [==============================] - 30s 706ms/step - loss: 0.4456 - accuracy: 0.8340 - val_loss: 0.3023 - val_accuracy: 0.8662
# Epoch 2/20
# 15/15 [==============================] - 12s 668ms/step - loss: 0.3310 - accuracy: 0.8340 - val_loss: 0.2430 - val_accuracy: 0.8872
# Epoch 3/20
# 15/15 [==============================] - 12s 674ms/step - loss: 0.2449 - accuracy: 0.8851 - val_loss: 0.3390 - val_accuracy: 0.8298
# Epoch 4/20
# 15/15 [==============================] - 12s 667ms/step - loss: 0.2229 - accuracy: 0.9000 - val_loss: 0.2488 - val_accuracy: 0.8987
# Epoch 5/20
# 15/15 [==============================] - 12s 666ms/step - loss: 0.1573 - accuracy: 0.9319 - val_loss: 0.2341 - val_accuracy: 0.9082
# Epoch 6/20
# 15/15 [==============================] - 12s 670ms/step - loss: 0.1534 - accuracy: 0.9319 - val_loss: 0.2109 - val_accuracy: 0.9159
# Epoch 7/20
# 15/15 [==============================] - 12s 670ms/step - loss: 0.1369 - accuracy: 0.9489 - val_loss: 0.2776 - val_accuracy: 0.9197
# Epoch 8/20
# 15/15 [==============================] - 12s 660ms/step - loss: 0.1161 - accuracy: 0.9660 - val_loss: 0.1846 - val_accuracy: 0.9235
# Epoch 9/20
# 15/15 [==============================] - 12s 647ms/step - loss: 0.1510 - accuracy: 0.9404 - val_loss: 0.2747 - val_accuracy: 0.9120
# Epoch 10/20
# 15/15 [==============================] - 12s 668ms/step - loss: 0.1033 - accuracy: 0.9574 - val_loss: 0.2268 - val_accuracy: 0.9235
# Epoch 11/20
# 15/15 [==============================] - 12s 664ms/step - loss: 0.0886 - accuracy: 0.9660 - val_loss: 0.2881 - val_accuracy: 0.9082
# Epoch 12/20
# 15/15 [==============================] - 12s 652ms/step - loss: 0.1229 - accuracy: 0.9553 - val_loss: 0.1859 - val_accuracy: 0.9331
# Epoch 13/20
# 15/15 [==============================] - 12s 662ms/step - loss: 0.0872 - accuracy: 0.9681 - val_loss: 0.1956 - val_accuracy: 0.9369
# Epoch 14/20
# 15/15 [==============================] - 12s 666ms/step - loss: 0.0636 - accuracy: 0.9745 - val_loss: 0.1939 - val_accuracy: 0.9369
# Epoch 15/20
# 15/15 [==============================] - 12s 664ms/step - loss: 0.0606 - accuracy: 0.9723 - val_loss: 0.2398 - val_accuracy: 0.9350
# Epoch 16/20
# 15/15 [==============================] - 12s 664ms/step - loss: 0.0688 - accuracy: 0.9745 - val_loss: 0.1570 - val_accuracy: 0.9369
# Epoch 17/20
# 15/15 [==============================] - 12s 667ms/step - loss: 0.0592 - accuracy: 0.9745 - val_loss: 0.2569 - val_accuracy: 0.9369
# Epoch 18/20
# 15/15 [==============================] - 12s 661ms/step - loss: 0.0690 - accuracy: 0.9766 - val_loss: 0.2139 - val_accuracy: 0.9312
# Epoch 19/20
# 15/15 [==============================] - 12s 669ms/step - loss: 0.0755 - accuracy: 0.9745 - val_loss: 0.2425 - val_accuracy: 0.9312
# Epoch 20/20
# 15/15 [==============================] - 12s 655ms/step - loss: 0.0437 - accuracy: 0.9809 - val_loss: 0.1860 - val_accuracy: 0.9350
# 20/20 [==============================] - 1s 42ms/step - loss: 2.4740 - accuracy: 0.6138
#
# === A1 training on 25% of pool ===
# Epoch 1/20
# 37/37 [==============================] - 30s 295ms/step - loss: 0.3981 - accuracy: 0.8505 - val_loss: 0.2750 - val_accuracy: 0.8795
# Epoch 2/20
# 37/37 [==============================] - 14s 284ms/step - loss: 0.2515 - accuracy: 0.8929 - val_loss: 0.2541 - val_accuracy: 0.8872
# Epoch 3/20
# 37/37 [==============================] - 14s 288ms/step - loss: 0.2019 - accuracy: 0.9133 - val_loss: 0.2016 - val_accuracy: 0.9235
# Epoch 4/20
# 37/37 [==============================] - 14s 284ms/step - loss: 0.1631 - accuracy: 0.9414 - val_loss: 0.2255 - val_accuracy: 0.9140
# Epoch 5/20
# 37/37 [==============================] - 14s 284ms/step - loss: 0.1439 - accuracy: 0.9439 - val_loss: 0.2005 - val_accuracy: 0.9331
# Epoch 6/20
# 37/37 [==============================] - 14s 285ms/step - loss: 0.1363 - accuracy: 0.9465 - val_loss: 0.1851 - val_accuracy: 0.9312
# Epoch 7/20
# 37/37 [==============================] - 14s 283ms/step - loss: 0.0743 - accuracy: 0.9720 - val_loss: 0.2764 - val_accuracy: 0.9082
# Epoch 8/20
# 37/37 [==============================] - 14s 284ms/step - loss: 0.1366 - accuracy: 0.9482 - val_loss: 0.1412 - val_accuracy: 0.9407
# Epoch 9/20
# 37/37 [==============================] - 14s 284ms/step - loss: 0.0852 - accuracy: 0.9745 - val_loss: 0.1231 - val_accuracy: 0.9465
# Epoch 10/20
# 37/37 [==============================] - 14s 282ms/step - loss: 0.0608 - accuracy: 0.9813 - val_loss: 0.1339 - val_accuracy: 0.9560
# Epoch 11/20
# 37/37 [==============================] - 13s 281ms/step - loss: 0.0647 - accuracy: 0.9779 - val_loss: 0.2226 - val_accuracy: 0.9312
# Epoch 12/20
# 37/37 [==============================] - 14s 284ms/step - loss: 0.0648 - accuracy: 0.9779 - val_loss: 0.2065 - val_accuracy: 0.9407
# Epoch 13/20
# 37/37 [==============================] - 14s 283ms/step - loss: 0.0565 - accuracy: 0.9839 - val_loss: 0.0942 - val_accuracy: 0.9637
# Epoch 14/20
# 37/37 [==============================] - 14s 287ms/step - loss: 0.0317 - accuracy: 0.9881 - val_loss: 0.1441 - val_accuracy: 0.9579
# Epoch 15/20
# 37/37 [==============================] - 14s 285ms/step - loss: 0.0539 - accuracy: 0.9771 - val_loss: 0.1405 - val_accuracy: 0.9694
# Epoch 16/20
# 37/37 [==============================] - 14s 288ms/step - loss: 0.0360 - accuracy: 0.9890 - val_loss: 0.1187 - val_accuracy: 0.9618
# Epoch 17/20
# 37/37 [==============================] - 13s 281ms/step - loss: 0.0519 - accuracy: 0.9796 - val_loss: 0.1685 - val_accuracy: 0.9522
# Epoch 18/20
# 37/37 [==============================] - 14s 283ms/step - loss: 0.0223 - accuracy: 0.9890 - val_loss: 0.1203 - val_accuracy: 0.9694
# Epoch 19/20
# 37/37 [==============================] - 14s 284ms/step - loss: 0.0297 - accuracy: 0.9864 - val_loss: 0.2796 - val_accuracy: 0.9426
# Epoch 20/20
# 37/37 [==============================] - 14s 289ms/step - loss: 0.0429 - accuracy: 0.9839 - val_loss: 0.1896 - val_accuracy: 0.9407
# 20/20 [==============================] - 1s 42ms/step - loss: 3.2692 - accuracy: 0.6506
#
# === A1 training on 50% of pool ===
# Epoch 1/20
# 74/74 [==============================] - 33s 175ms/step - loss: 0.3175 - accuracy: 0.8649 - val_loss: 0.1890 - val_accuracy: 0.9197
# Epoch 2/20
# 74/74 [==============================] - 16s 168ms/step - loss: 0.1882 - accuracy: 0.9261 - val_loss: 0.1551 - val_accuracy: 0.9388
# Epoch 3/20
# 74/74 [==============================] - 16s 168ms/step - loss: 0.1332 - accuracy: 0.9494 - val_loss: 0.1056 - val_accuracy: 0.9675
# Epoch 4/20
# 74/74 [==============================] - 16s 169ms/step - loss: 0.1167 - accuracy: 0.9579 - val_loss: 0.1381 - val_accuracy: 0.9465
# Epoch 5/20
# 74/74 [==============================] - 16s 167ms/step - loss: 0.0792 - accuracy: 0.9681 - val_loss: 0.1122 - val_accuracy: 0.9675
# Epoch 6/20
# 74/74 [==============================] - 16s 169ms/step - loss: 0.0879 - accuracy: 0.9677 - val_loss: 0.1028 - val_accuracy: 0.9732
# Epoch 7/20
# 74/74 [==============================] - 16s 167ms/step - loss: 0.0649 - accuracy: 0.9775 - val_loss: 0.0909 - val_accuracy: 0.9637
# Epoch 8/20
# 74/74 [==============================] - 16s 169ms/step - loss: 0.0439 - accuracy: 0.9860 - val_loss: 0.0765 - val_accuracy: 0.9847
# Epoch 9/20
# 74/74 [==============================] - 16s 167ms/step - loss: 0.0437 - accuracy: 0.9830 - val_loss: 0.1189 - val_accuracy: 0.9618
# Epoch 10/20
# 74/74 [==============================] - 16s 166ms/step - loss: 0.0653 - accuracy: 0.9762 - val_loss: 0.1091 - val_accuracy: 0.9618
# Epoch 11/20
# 74/74 [==============================] - 16s 167ms/step - loss: 0.0693 - accuracy: 0.9749 - val_loss: 0.0790 - val_accuracy: 0.9713
# Epoch 12/20
# 74/74 [==============================] - 16s 168ms/step - loss: 0.0335 - accuracy: 0.9877 - val_loss: 0.1487 - val_accuracy: 0.9484
# Epoch 13/20
# 74/74 [==============================] - 16s 167ms/step - loss: 0.0224 - accuracy: 0.9907 - val_loss: 0.0969 - val_accuracy: 0.9694
# Epoch 14/20
# 74/74 [==============================] - 16s 171ms/step - loss: 0.0359 - accuracy: 0.9873 - val_loss: 0.1436 - val_accuracy: 0.9598
# Epoch 15/20
# 74/74 [==============================] - 16s 168ms/step - loss: 0.0616 - accuracy: 0.9813 - val_loss: 0.0827 - val_accuracy: 0.9713
# Epoch 16/20
# 74/74 [==============================] - 16s 169ms/step - loss: 0.0327 - accuracy: 0.9873 - val_loss: 0.0666 - val_accuracy: 0.9828
# Epoch 17/20
# 74/74 [==============================] - 16s 167ms/step - loss: 0.0521 - accuracy: 0.9805 - val_loss: 0.1213 - val_accuracy: 0.9694
# Epoch 18/20
# 74/74 [==============================] - 16s 167ms/step - loss: 0.0489 - accuracy: 0.9834 - val_loss: 0.1159 - val_accuracy: 0.9637
# Epoch 19/20
# 74/74 [==============================] - 16s 168ms/step - loss: 0.0306 - accuracy: 0.9890 - val_loss: 0.1046 - val_accuracy: 0.9598
# Epoch 20/20
# 74/74 [==============================] - 16s 168ms/step - loss: 0.0323 - accuracy: 0.9890 - val_loss: 0.1415 - val_accuracy: 0.9656
# 20/20 [==============================] - 1s 42ms/step - loss: 3.3902 - accuracy: 0.6282
#
# === A1 training on 100% of pool ===
# Epoch 1/20
# 148/148 [==============================] - 36s 113ms/step - loss: 0.2849 - accuracy: 0.8787 - val_loss: 0.1517 - val_accuracy: 0.9369
# Epoch 2/20
# 148/148 [==============================] - 20s 112ms/step - loss: 0.1387 - accuracy: 0.9484 - val_loss: 0.0594 - val_accuracy: 0.9732
# Epoch 3/20
# 148/148 [==============================] - 20s 110ms/step - loss: 0.1003 - accuracy: 0.9641 - val_loss: 0.0966 - val_accuracy: 0.9579
# Epoch 4/20
# 148/148 [==============================] - 20s 112ms/step - loss: 0.0780 - accuracy: 0.9696 - val_loss: 0.0595 - val_accuracy: 0.9790
# Epoch 5/20
# 148/148 [==============================] - 19s 109ms/step - loss: 0.0678 - accuracy: 0.9745 - val_loss: 0.0512 - val_accuracy: 0.9866
# Epoch 6/20
# 148/148 [==============================] - 20s 110ms/step - loss: 0.0627 - accuracy: 0.9764 - val_loss: 0.0343 - val_accuracy: 0.9885
# Epoch 7/20
# 148/148 [==============================] - 20s 110ms/step - loss: 0.0457 - accuracy: 0.9826 - val_loss: 0.0709 - val_accuracy: 0.9694
# Epoch 8/20
# 148/148 [==============================] - 20s 110ms/step - loss: 0.0492 - accuracy: 0.9822 - val_loss: 0.0609 - val_accuracy: 0.9809
# Epoch 9/20
# 148/148 [==============================] - 20s 111ms/step - loss: 0.0352 - accuracy: 0.9870 - val_loss: 0.0758 - val_accuracy: 0.9751
# Epoch 10/20
# 148/148 [==============================] - 20s 110ms/step - loss: 0.0395 - accuracy: 0.9862 - val_loss: 0.0230 - val_accuracy: 0.9943
# Epoch 11/20
# 148/148 [==============================] - 20s 112ms/step - loss: 0.0353 - accuracy: 0.9877 - val_loss: 0.0288 - val_accuracy: 0.9885
# Epoch 12/20
# 148/148 [==============================] - 19s 109ms/step - loss: 0.0359 - accuracy: 0.9856 - val_loss: 0.0496 - val_accuracy: 0.9790
# Epoch 13/20
# 148/148 [==============================] - 19s 109ms/step - loss: 0.0527 - accuracy: 0.9781 - val_loss: 0.0324 - val_accuracy: 0.9885
# Epoch 14/20
# 148/148 [==============================] - 20s 112ms/step - loss: 0.0426 - accuracy: 0.9841 - val_loss: 0.0246 - val_accuracy: 0.9943
# Epoch 15/20
# 148/148 [==============================] - 20s 111ms/step - loss: 0.0210 - accuracy: 0.9932 - val_loss: 0.0112 - val_accuracy: 0.9943
# Epoch 16/20
# 148/148 [==============================] - 20s 111ms/step - loss: 0.0252 - accuracy: 0.9917 - val_loss: 0.0085 - val_accuracy: 0.9981
# Epoch 17/20
# 148/148 [==============================] - 20s 110ms/step - loss: 0.0373 - accuracy: 0.9864 - val_loss: 0.0216 - val_accuracy: 0.9943
# Epoch 18/20
# 148/148 [==============================] - 20s 111ms/step - loss: 0.0323 - accuracy: 0.9879 - val_loss: 0.0177 - val_accuracy: 0.9924
# Epoch 19/20
# 148/148 [==============================] - 19s 110ms/step - loss: 0.0381 - accuracy: 0.9847 - val_loss: 0.0232 - val_accuracy: 0.9943
# Epoch 20/20
# 148/148 [==============================] - 20s 109ms/step - loss: 0.0247 - accuracy: 0.9904 - val_loss: 0.0093 - val_accuracy: 0.9962
# 20/20 [==============================] - 1s 42ms/step - loss: 3.0201 - accuracy: 0.6843
# A1 test metrics per subset: {'10%': {'loss': 2.473989725112915, 'accuracy': 0.6137820482254028}, '25%': {'loss': 3.2691853046417236, 'accuracy': 0.6506410241127014}, '50%': {'loss': 3.3901610374450684, 'accuracy': 0.6282051205635071}, '100%': {'loss': 3.0200698375701904, 'accuracy': 0.6842948794364929}}

# %%
# ====================================================
# 7. Train Model A2 (BACTERIA vs VIRUS)
# ====================================================
a2_subsets = {
    "10%": train_A2_10,
    "25%": train_A2_25,
    "50%": train_A2_50,
    "100%": train_A2_100,
}

histories_A2 = {}
tests_A2 = {}
models_A2 = OrderedDict() 

for name, train_ds in a2_subsets.items():
    print(f"\n=== A2 training on {name} of pool ===")
    model = make_classifier(num_classes=2)
    history = model.fit(
        train_ds,
        epochs=EPOCHS,
        validation_data=val_A2,
        validation_steps=val_steps_A2,
    )
    histories_A2[name] = history.history
    tests_A2[name] = model.evaluate(test_A2, return_dict=True)
    models_A2[name] = model          

print("A2 test metrics per subset:", tests_A2)
# Out:
# === A2 training on 10% of pool ===
# Epoch 1/20
# 11/11 [==============================] - 22s 480ms/step - loss: 0.8377 - accuracy: 0.5903 - val_loss: 0.8670 - val_accuracy: 0.5885
# Epoch 2/20
# 11/11 [==============================] - 5s 411ms/step - loss: 0.7661 - accuracy: 0.6189 - val_loss: 0.6337 - val_accuracy: 0.6536
# Epoch 3/20
# 11/11 [==============================] - 5s 411ms/step - loss: 0.6862 - accuracy: 0.6590 - val_loss: 0.7409 - val_accuracy: 0.6094
# Epoch 4/20
# 11/11 [==============================] - 5s 413ms/step - loss: 0.6732 - accuracy: 0.6504 - val_loss: 0.7442 - val_accuracy: 0.6406
# Epoch 5/20
# 11/11 [==============================] - 6s 449ms/step - loss: 0.6675 - accuracy: 0.7020 - val_loss: 0.5456 - val_accuracy: 0.7526
# Epoch 6/20
# 11/11 [==============================] - 5s 412ms/step - loss: 0.5771 - accuracy: 0.7049 - val_loss: 0.5729 - val_accuracy: 0.7214
# Epoch 7/20
# 11/11 [==============================] - 6s 435ms/step - loss: 0.5373 - accuracy: 0.7622 - val_loss: 0.5899 - val_accuracy: 0.7135
# Epoch 8/20
# 11/11 [==============================] - 6s 428ms/step - loss: 0.5375 - accuracy: 0.7278 - val_loss: 0.6297 - val_accuracy: 0.6484
# Epoch 9/20
# 11/11 [==============================] - 5s 406ms/step - loss: 0.5310 - accuracy: 0.7393 - val_loss: 0.5593 - val_accuracy: 0.7161
# Epoch 10/20
# 11/11 [==============================] - 6s 437ms/step - loss: 0.5137 - accuracy: 0.7507 - val_loss: 0.6095 - val_accuracy: 0.7344
# Epoch 11/20
# 11/11 [==============================] - 5s 413ms/step - loss: 0.4723 - accuracy: 0.8023 - val_loss: 0.5647 - val_accuracy: 0.7135
# Epoch 12/20
# 11/11 [==============================] - 5s 405ms/step - loss: 0.4087 - accuracy: 0.8138 - val_loss: 0.6519 - val_accuracy: 0.7109
# Epoch 13/20
# 11/11 [==============================] - 6s 424ms/step - loss: 0.4617 - accuracy: 0.7937 - val_loss: 0.6101 - val_accuracy: 0.7318
# Epoch 14/20
# 11/11 [==============================] - 5s 408ms/step - loss: 0.4556 - accuracy: 0.7880 - val_loss: 0.7052 - val_accuracy: 0.6615
# Epoch 15/20
# 11/11 [==============================] - 5s 414ms/step - loss: 0.5528 - accuracy: 0.7479 - val_loss: 0.6447 - val_accuracy: 0.7057
# Epoch 16/20
# 11/11 [==============================] - 5s 409ms/step - loss: 0.4669 - accuracy: 0.7908 - val_loss: 0.7473 - val_accuracy: 0.6641
# Epoch 17/20
# 11/11 [==============================] - 6s 421ms/step - loss: 0.4423 - accuracy: 0.7937 - val_loss: 0.6411 - val_accuracy: 0.6901
# Epoch 18/20
# 11/11 [==============================] - 6s 414ms/step - loss: 0.4297 - accuracy: 0.8195 - val_loss: 0.7642 - val_accuracy: 0.6458
# Epoch 19/20
# 11/11 [==============================] - 6s 442ms/step - loss: 0.4213 - accuracy: 0.8052 - val_loss: 0.7520 - val_accuracy: 0.6406
# Epoch 20/20
# 11/11 [==============================] - 6s 419ms/step - loss: 0.4345 - accuracy: 0.8367 - val_loss: 0.8311 - val_accuracy: 0.6823
# 13/13 [==============================] - 0s 26ms/step - loss: 1.0062 - accuracy: 0.5923
#
# === A2 training on 25% of pool ===
# Epoch 1/20
# 28/28 [==============================] - 23s 204ms/step - loss: 0.7024 - accuracy: 0.6518 - val_loss: 0.7472 - val_accuracy: 0.7109
# Epoch 2/20
# 28/28 [==============================] - 7s 179ms/step - loss: 0.6302 - accuracy: 0.6987 - val_loss: 0.6290 - val_accuracy: 0.7005
# Epoch 3/20
# 28/28 [==============================] - 7s 178ms/step - loss: 0.5931 - accuracy: 0.6827 - val_loss: 0.5761 - val_accuracy: 0.7005
# Epoch 4/20
# 28/28 [==============================] - 7s 179ms/step - loss: 0.6071 - accuracy: 0.6919 - val_loss: 0.5542 - val_accuracy: 0.7578
# Epoch 5/20
# 28/28 [==============================] - 7s 179ms/step - loss: 0.5717 - accuracy: 0.7285 - val_loss: 0.6259 - val_accuracy: 0.6901
# Epoch 6/20
# 28/28 [==============================] - 7s 181ms/step - loss: 0.5347 - accuracy: 0.7457 - val_loss: 0.6452 - val_accuracy: 0.6797
# Epoch 7/20
# 28/28 [==============================] - 7s 182ms/step - loss: 0.5696 - accuracy: 0.7228 - val_loss: 0.6374 - val_accuracy: 0.6823
# Epoch 8/20
# 28/28 [==============================] - 7s 177ms/step - loss: 0.4771 - accuracy: 0.7858 - val_loss: 0.5851 - val_accuracy: 0.7005
# Epoch 9/20
# 28/28 [==============================] - 7s 177ms/step - loss: 0.4786 - accuracy: 0.7892 - val_loss: 0.6067 - val_accuracy: 0.6979
# Epoch 10/20
# 28/28 [==============================] - 7s 180ms/step - loss: 0.4672 - accuracy: 0.7858 - val_loss: 0.8060 - val_accuracy: 0.6328
# Epoch 11/20
# 28/28 [==============================] - 7s 181ms/step - loss: 0.4870 - accuracy: 0.7709 - val_loss: 0.5832 - val_accuracy: 0.7109
# Epoch 12/20
# 28/28 [==============================] - 7s 181ms/step - loss: 0.4651 - accuracy: 0.7812 - val_loss: 0.6112 - val_accuracy: 0.7031
# Epoch 13/20
# 28/28 [==============================] - 7s 184ms/step - loss: 0.4343 - accuracy: 0.7938 - val_loss: 0.6019 - val_accuracy: 0.6979
# Epoch 14/20
# 28/28 [==============================] - 7s 181ms/step - loss: 0.3861 - accuracy: 0.8293 - val_loss: 0.6342 - val_accuracy: 0.7422
# Epoch 15/20
# 28/28 [==============================] - 7s 180ms/step - loss: 0.3088 - accuracy: 0.8625 - val_loss: 0.6352 - val_accuracy: 0.7526
# Epoch 16/20
# 28/28 [==============================] - 7s 181ms/step - loss: 0.3516 - accuracy: 0.8477 - val_loss: 0.5943 - val_accuracy: 0.6953
# Epoch 17/20
# 28/28 [==============================] - 7s 182ms/step - loss: 0.3428 - accuracy: 0.8545 - val_loss: 0.6751 - val_accuracy: 0.6953
# Epoch 18/20
# 28/28 [==============================] - 7s 182ms/step - loss: 0.2921 - accuracy: 0.8820 - val_loss: 0.8016 - val_accuracy: 0.6797
# Epoch 19/20
# 28/28 [==============================] - 7s 181ms/step - loss: 0.3537 - accuracy: 0.8511 - val_loss: 0.6457 - val_accuracy: 0.7031
# Epoch 20/20
# 28/28 [==============================] - 7s 180ms/step - loss: 0.2684 - accuracy: 0.8843 - val_loss: 0.9110 - val_accuracy: 0.6719
# 13/13 [==============================] - 0s 27ms/step - loss: 1.3175 - accuracy: 0.5436
#
# === A2 training on 50% of pool ===
# Epoch 1/20
# 55/55 [==============================] - 25s 126ms/step - loss: 0.6622 - accuracy: 0.6720 - val_loss: 0.6090 - val_accuracy: 0.6875
# Epoch 2/20
# 55/55 [==============================] - 8s 114ms/step - loss: 0.5784 - accuracy: 0.7287 - val_loss: 0.5783 - val_accuracy: 0.7318
# Epoch 3/20
# 55/55 [==============================] - 8s 111ms/step - loss: 0.5525 - accuracy: 0.7401 - val_loss: 0.5518 - val_accuracy: 0.7031
# Epoch 4/20
# 55/55 [==============================] - 8s 113ms/step - loss: 0.5362 - accuracy: 0.7447 - val_loss: 0.5625 - val_accuracy: 0.7344
# Epoch 5/20
# 55/55 [==============================] - 8s 110ms/step - loss: 0.5189 - accuracy: 0.7298 - val_loss: 0.5301 - val_accuracy: 0.7500
# Epoch 6/20
# 55/55 [==============================] - 8s 110ms/step - loss: 0.5144 - accuracy: 0.7481 - val_loss: 0.4976 - val_accuracy: 0.7422
# Epoch 7/20
# 55/55 [==============================] - 8s 118ms/step - loss: 0.4666 - accuracy: 0.7876 - val_loss: 0.5650 - val_accuracy: 0.7344
# Epoch 8/20
# 55/55 [==============================] - 8s 111ms/step - loss: 0.4820 - accuracy: 0.7779 - val_loss: 0.5660 - val_accuracy: 0.7057
# Epoch 9/20
# 55/55 [==============================] - 8s 113ms/step - loss: 0.4498 - accuracy: 0.7928 - val_loss: 0.5292 - val_accuracy: 0.7552
# Epoch 10/20
# 55/55 [==============================] - 8s 111ms/step - loss: 0.3988 - accuracy: 0.8203 - val_loss: 0.5196 - val_accuracy: 0.7760
# Epoch 11/20
# 55/55 [==============================] - 8s 112ms/step - loss: 0.3839 - accuracy: 0.8231 - val_loss: 0.4731 - val_accuracy: 0.7943
# Epoch 12/20
# 55/55 [==============================] - 8s 112ms/step - loss: 0.3778 - accuracy: 0.8380 - val_loss: 0.5521 - val_accuracy: 0.7266
# Epoch 13/20
# 55/55 [==============================] - 8s 115ms/step - loss: 0.3708 - accuracy: 0.8374 - val_loss: 0.4936 - val_accuracy: 0.7865
# Epoch 14/20
# 55/55 [==============================] - 8s 112ms/step - loss: 0.3426 - accuracy: 0.8552 - val_loss: 0.5513 - val_accuracy: 0.7630
# Epoch 15/20
# 55/55 [==============================] - 8s 112ms/step - loss: 0.2986 - accuracy: 0.8798 - val_loss: 0.6169 - val_accuracy: 0.7396
# Epoch 16/20
# 55/55 [==============================] - 8s 114ms/step - loss: 0.3032 - accuracy: 0.8701 - val_loss: 0.5744 - val_accuracy: 0.7526
# Epoch 17/20
# 55/55 [==============================] - 8s 111ms/step - loss: 0.2322 - accuracy: 0.9090 - val_loss: 0.6916 - val_accuracy: 0.7318
# Epoch 18/20
# 55/55 [==============================] - 8s 112ms/step - loss: 0.2217 - accuracy: 0.9181 - val_loss: 0.6716 - val_accuracy: 0.7630
# Epoch 19/20
# 55/55 [==============================] - 8s 115ms/step - loss: 0.2760 - accuracy: 0.8872 - val_loss: 0.6743 - val_accuracy: 0.7005
# Epoch 20/20
# 55/55 [==============================] - 8s 112ms/step - loss: 0.2347 - accuracy: 0.9021 - val_loss: 0.6311 - val_accuracy: 0.7500
# 13/13 [==============================] - 0s 27ms/step - loss: 1.0147 - accuracy: 0.6205
#
# === A2 training on 100% of pool ===
# Epoch 1/20
# 110/110 [==============================] - 28s 82ms/step - loss: 0.6328 - accuracy: 0.6973 - val_loss: 0.5480 - val_accuracy: 0.7318
# Epoch 2/20
# 110/110 [==============================] - 10s 76ms/step - loss: 0.5898 - accuracy: 0.7133 - val_loss: 0.5542 - val_accuracy: 0.7474
# Epoch 3/20
# 110/110 [==============================] - 11s 79ms/step - loss: 0.5516 - accuracy: 0.7299 - val_loss: 0.4922 - val_accuracy: 0.7604
# Epoch 4/20
# 110/110 [==============================] - 10s 78ms/step - loss: 0.5318 - accuracy: 0.7445 - val_loss: 0.5240 - val_accuracy: 0.7005
# Epoch 5/20
# 110/110 [==============================] - 10s 76ms/step - loss: 0.5077 - accuracy: 0.7545 - val_loss: 0.4198 - val_accuracy: 0.8359
# Epoch 6/20
# 110/110 [==============================] - 10s 76ms/step - loss: 0.4966 - accuracy: 0.7651 - val_loss: 0.4094 - val_accuracy: 0.7995
# Epoch 7/20
# 110/110 [==============================] - 11s 79ms/step - loss: 0.4763 - accuracy: 0.7791 - val_loss: 0.3958 - val_accuracy: 0.8516
# Epoch 8/20
# 110/110 [==============================] - 10s 76ms/step - loss: 0.4741 - accuracy: 0.7794 - val_loss: 0.4246 - val_accuracy: 0.8307
# Epoch 9/20
# 110/110 [==============================] - 10s 76ms/step - loss: 0.4568 - accuracy: 0.7914 - val_loss: 0.4401 - val_accuracy: 0.7969
# Epoch 10/20
# 110/110 [==============================] - 11s 78ms/step - loss: 0.4390 - accuracy: 0.7963 - val_loss: 0.3589 - val_accuracy: 0.8438
# Epoch 11/20
# 110/110 [==============================] - 11s 78ms/step - loss: 0.4054 - accuracy: 0.8029 - val_loss: 0.3572 - val_accuracy: 0.8464
# Epoch 12/20
# 110/110 [==============================] - 11s 79ms/step - loss: 0.3790 - accuracy: 0.8315 - val_loss: 0.3448 - val_accuracy: 0.8594
# Epoch 13/20
# 110/110 [==============================] - 10s 76ms/step - loss: 0.3552 - accuracy: 0.8481 - val_loss: 0.2580 - val_accuracy: 0.8828
# Epoch 14/20
# 110/110 [==============================] - 11s 77ms/step - loss: 0.3340 - accuracy: 0.8521 - val_loss: 0.2937 - val_accuracy: 0.8854
# Epoch 15/20
# 110/110 [==============================] - 10s 78ms/step - loss: 0.3115 - accuracy: 0.8698 - val_loss: 0.2476 - val_accuracy: 0.9062
# Epoch 16/20
# 110/110 [==============================] - 11s 78ms/step - loss: 0.2853 - accuracy: 0.8753 - val_loss: 0.1944 - val_accuracy: 0.9479
# Epoch 17/20
# 110/110 [==============================] - 10s 77ms/step - loss: 0.2754 - accuracy: 0.8864 - val_loss: 0.1890 - val_accuracy: 0.9245
# Epoch 18/20
# 110/110 [==============================] - 10s 77ms/step - loss: 0.2706 - accuracy: 0.8850 - val_loss: 0.1777 - val_accuracy: 0.9245
# Epoch 19/20
# 110/110 [==============================] - 11s 78ms/step - loss: 0.2409 - accuracy: 0.8990 - val_loss: 0.2096 - val_accuracy: 0.9141
# Epoch 20/20
# 110/110 [==============================] - 11s 78ms/step - loss: 0.2087 - accuracy: 0.9167 - val_loss: 0.1401 - val_accuracy: 0.9531
# 13/13 [==============================] - 0s 28ms/step - loss: 1.1522 - accuracy: 0.6103
# A2 test metrics per subset: {'10%': {'loss': 1.006224513053894, 'accuracy': 0.5923076868057251}, '25%': {'loss': 1.3174622058868408, 'accuracy': 0.5435897707939148}, '50%': {'loss': 1.0147258043289185, 'accuracy': 0.620512843132019}, '100%': {'loss': 1.152221441268921, 'accuracy': 0.6102564334869385}}

# %%
# ====================================================
# Plot histories for all subsets
# ====================================================

class HistoryWrapper:
    def __init__(self, hist_dict):
        self.history = hist_dict

# existing plotting function (unchanged)
def plot_history(history, title_prefix="Model"):
    acc = history.history.get("accuracy", [])
    val_acc = history.history.get("val_accuracy", [])
    loss = history.history.get("loss", [])
    val_loss = history.history.get("val_loss", [])

    plt.figure(figsize=(12, 4))

    # Accuracy
    plt.subplot(1, 2, 1)
    if acc:
        epochs_acc = range(1, len(acc) + 1)
        plt.plot(epochs_acc, acc, "bo-", label="train acc")
    if val_acc:
        epochs_val_acc = range(1, len(val_acc) + 1)
        plt.plot(epochs_val_acc, val_acc, "ro-", label="val acc")
    plt.title(f"{title_prefix} accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()

    # Loss
    plt.subplot(1, 2, 2)
    if loss:
        epochs_loss = range(1, len(loss) + 1)
        plt.plot(epochs_loss, loss, "bo-", label="train loss")
    if val_loss:
        epochs_val_loss = range(1, len(val_loss) + 1)
        plt.plot(epochs_val_loss, val_loss, "ro-", label="val loss")
    plt.title(f"{title_prefix} loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()

    plt.tight_layout()
    plt.show()

# plot all A1 subset runs
for frac, hist_dict in histories_A1.items():
    plot_history(HistoryWrapper(hist_dict),
                 title_prefix=f"A1 NORMAL vs PNEUMONIA ({frac})")

# plot all A2 subset runs
for frac, hist_dict in histories_A2.items():
    plot_history(HistoryWrapper(hist_dict),
                 title_prefix=f"A2 BACTERIA vs VIRUS ({frac})")

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report

def eval_with_confusion(model, test_ds, class_names, title="Model"):
    y_true = []
    y_pred = []

    for images, labels in test_ds:
        preds = model.predict(images, verbose=0)
        preds_labels = np.argmax(preds, axis=1)
        y_true.extend(labels.numpy())
        y_pred.extend(preds_labels)

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)

    cm = confusion_matrix(y_true, y_pred, labels=range(len(class_names)))
    print(f"\n{title} - Confusion matrix")
    print(cm)

    print(f"\n{title} - Classification report")
    print(classification_report(y_true, y_pred, target_names=class_names))

# %%
class_names_A1 = ["NORMAL", "PNEUMONIA"]
class_names_A2 = ["BACTERIA", "VIRUS"]

# A1: NORMAL vs PNEUMONIA
for name, model in models_A1.items():
    eval_with_confusion(
        model,
        test_A1,
        class_names_A1,
        title=f"A1 ({name} train pool)"
    )

# A2: BACTERIA vs VIRUS
for name, model in models_A2.items():
    eval_with_confusion(
        model,
        test_A2,
        class_names_A2,
        title=f"A2 ({name} train pool)"
    )
# Out:
# A1 (10% train pool) - Confusion matrix
# [[ 54 180]
#  [ 61 329]]
#
# A1 (10% train pool) - Classification report
#               precision    recall  f1-score   support
#
#       NORMAL       0.47      0.23      0.31       234
#    PNEUMONIA       0.65      0.84      0.73       390
#
#     accuracy                           0.61       624
#    macro avg       0.56      0.54      0.52       624
# weighted avg       0.58      0.61      0.57       624
#
#
# A1 (25% train pool) - Confusion matrix
# [[ 59 175]
#  [ 43 347]]
#
# A1 (25% train pool) - Classification report
#               precision    recall  f1-score   support
#
#       NORMAL       0.58      0.25      0.35       234
#    PNEUMONIA       0.66      0.89      0.76       390
#
#     accuracy                           0.65       624
#    macro avg       0.62      0.57      0.56       624
# weighted avg       0.63      0.65      0.61       624
#
#
# A1 (50% train pool) - Confusion matrix
# [[ 72 162]
#  [ 70 320]]
#
# A1 (50% train pool) - Classification report
#               precision    recall  f1-score   support
#
#       NORMAL       0.51      0.31      0.38       234
#    PNEUMONIA       0.66      0.82      0.73       390
#
#     accuracy                           0.63       624
#    macro avg       0.59      0.56      0.56       624
# weighted avg       0.61      0.63      0.60       624
#
#
# A1 (100% train pool) - Confusion matrix
# [[ 61 173]
#  [ 24 366]]
#
# A1 (100% train pool) - Classification report
#               precision    recall  f1-score   support
#
#       NORMAL       0.72      0.26      0.38       234
#    PNEUMONIA       0.68      0.94      0.79       390
#
#     accuracy                           0.68       624
#    macro avg       0.70      0.60      0.59       624
# weighted avg       0.69      0.68      0.64       624
#
#
# A2 (10% train pool) - Confusion matrix
# [[202  40]
#  [119  29]]
#
# A2 (10% train pool) - Classification report
#               precision    recall  f1-score   support
#
#     BACTERIA       0.63      0.83      0.72       242
#        VIRUS       0.42      0.20      0.27       148
#
#     accuracy                           0.59       390
#    macro avg       0.52      0.52      0.49       390
# weighted avg       0.55      0.59      0.55       390
#
#
# A2 (25% train pool) - Confusion matrix
# [[151  91]
#  [ 87  61]]
#
# A2 (25% train pool) - Classification report
#               precision    recall  f1-score   support
#
#     BACTERIA       0.63      0.62      0.63       242
#        VIRUS       0.40      0.41      0.41       148
#
#     accuracy                           0.54       390
#    macro avg       0.52      0.52      0.52       390
# weighted avg       0.55      0.54      0.54       390
#
#
# A2 (50% train pool) - Confusion matrix
# [[181  61]
#  [ 87  61]]
#
# A2 (50% train pool) - Classification report
#               precision    recall  f1-score   support
#
#     BACTERIA       0.68      0.75      0.71       242
#        VIRUS       0.50      0.41      0.45       148
#
#     accuracy                           0.62       390
#    macro avg       0.59      0.58      0.58       390
# weighted avg       0.61      0.62      0.61       390
#
#
# A2 (100% train pool) - Confusion matrix
# [[193  49]
#  [103  45]]
#
# A2 (100% train pool) - Classification report
#               precision    recall  f1-score   support
#
#     BACTERIA       0.65      0.80      0.72       242
#        VIRUS       0.48      0.30      0.37       148
#
#     accuracy                           0.61       390
#    macro avg       0.57      0.55      0.54       390
# weighted avg       0.59      0.61      0.59       390
